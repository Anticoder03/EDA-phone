# %% [markdown]
# # 📊 Exploratory Data Analysis (EDA) – Mobile Price Dataset
#
# This notebook presents a complete Exploratory Data Analysis (EDA) of a mobile phone dataset.
#
# ---

# %% [markdown]
# ## 📌 Introduction
#
# The goal of this EDA is to:
# - Understand the dataset structure
# - Clean and prepare features
# - Analyze distributions and relationships
# - Derive insights about mobile phone pricing
#
# ---

# %% [markdown]
# ## 1️⃣ Understanding the Dataset
#
# - The dataset contains mobile phone specifications such as price, battery, display, RAM, ROM, camera, rating, reviews, brand, and warranty.
# - `price` is treated as the target variable.
# - Several numeric values are stored as text due to units.
#
# ---

# %% [markdown]
# ## 2️⃣ Data Quality Checks
#
# ### Missing Values Handling
#
# - **Processor** → Filled with `Unknown`
# - **Rating** → Filled using mean
# - **Reviews** → Filled using median
# - **Warranty** → Filled with `Not Mentioned`
#
# This avoids data loss and prevents false assumptions.
#
# ---

# %% [markdown]
# ## 3️⃣ Feature Extraction & Cleaning
#
# Converted textual numeric features into usable numeric columns:
#
# - Battery → mAh
# - Display size → numeric
# - Reviews → numeric count
# - Memory → split into RAM_GB and ROM_GB
# - Camera → primary rear camera MP
#
# ---

# %% [markdown]
# ## 4️⃣ Univariate Analysis
#
# **Key Observations:**
#
# - Price: Right-skewed
# - Rating: Left-skewed (positive bias)
# - Reviews: Highly right-skewed
# - Battery: Slightly left-skewed / near symmetric
# - Display: Left-skewed
# - RAM & ROM: Right-skewed
#
# ---

# %% [markdown]
# ## 5️⃣ Bivariate Analysis
#
# - Price vs Battery → Weak relationship
# - Price vs Display → Weak relationship
# - Price vs Rating → Very weak relationship
# - Price vs RAM → Moderate relationship with high variability at higher RAM
# - Price vs ROM → Stronger relationship
# - Price vs Camera → Weak to moderate
#
# ### Brand vs Price
#
# - Samsung: Widest price range, strong premium presence
# - Budget brands (Infinix, Lava, Nokia, Gionee, Honor): Consistent low pricing
# - Other brands: Moderate spread
#
# ---

# %% [markdown]
# ## 6️⃣ Correlation Analysis
#
# **Correlation with Price:**
#
# - ROM → Strong positive (~0.66)
# - Display, Camera, Rating → Moderate (~0.43–0.56)
# - Battery → Weak (~0.29)
# - RAM & Reviews → Negligible (~0)
#
# ---

# %% [markdown]
# ## ✅ Final EDA Conclusion
#
# - No single feature determines price.
# - ROM and brand positioning are the strongest influencers.
# - Hardware specs alone do not explain pricing.
# - Dataset is clean and ready for ML modeling.
#
# ---
#
# **EDA Completed Successfully** ✅
